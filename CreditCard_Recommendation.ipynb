# %%
import sys
# !{sys.executable} -m pip install pandas
# !pip install python-dotenv
# !pip install pandas numpy
# !pip install weaviate-client
# !pip install tavily-python
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/raghavdhuria/Library/Python/3.13/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/raghavdhuria/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: weaviate-client in /opt/anaconda3/lib/python3.13/site-packages (4.16.5)
# Requirement already satisfied: httpx<0.29.0,>=0.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (0.28.1)
# Requirement already satisfied: validators<1.0.0,>=0.34.0 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (0.35.0)
# Requirement already satisfied: authlib<2.0.0,>=1.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (1.6.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (2.10.3)
# Requirement already satisfied: grpcio<1.80.0,>=1.59.5 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (1.74.0)
# Requirement already satisfied: grpcio-health-checking<1.80.0,>=1.59.5 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (1.74.0)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from weaviate-client) (2.1.0)
# Requirement already satisfied: cryptography in /opt/anaconda3/lib/python3.13/site-packages (from authlib<2.0.0,>=1.2.1->weaviate-client) (44.0.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from deprecation<3.0.0,>=2.1.0->weaviate-client) (24.2)
# Requirement already satisfied: protobuf<7.0.0,>=6.31.1 in /opt/anaconda3/lib/python3.13/site-packages (from grpcio-health-checking<1.80.0,>=1.59.5->weaviate-client) (6.31.1)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<0.29.0,>=0.26.0->weaviate-client) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx<0.29.0,>=0.26.0->weaviate-client) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography->authlib<2.0.0,>=1.2.1->weaviate-client) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.2.1->weaviate-client) (2.21)
# Requirement already satisfied: tavily-python in /opt/anaconda3/lib/python3.13/site-packages (0.7.10)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from tavily-python) (2.32.3)
# Requirement already satisfied: tiktoken>=0.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from tavily-python) (0.9.0)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.13/site-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.13/site-packages (from tiktoken>=0.5.1->tavily-python) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->tavily-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->tavily-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->tavily-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->tavily-python) (2025.7.14)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx->tavily-python) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx->tavily-python) (1.3.0)

# %%
# CreditCard_Recommendation.ipynb
# Setup and Imports
from dotenv import load_dotenv
load_dotenv()
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
from IPython.display import display, HTML

# Load environment variables from .env file
load_dotenv()

# Get configuration variables from environment
config = {
    "weaviate_cluster_url": os.getenv("WEAVIATE_CLUSTER_URL"),
    "weaviate_api_key": os.getenv("WEAVIATE_API_KEY"),
    "tavily_api_key": os.getenv("TAVILY_API_KEY"),
    "credit_card_data_path": os.getenv("CREDIT_CARD_DATA_PATH")
}

print("Loaded configuration:")
print(config)

# Load your credit/debit card dataset using the provided path
file_path = config["credit_card_data_path"]

# Read Excel or CSV file based on file extension
if file_path.endswith(".xlsx") or file_path.endswith(".xls"):
    df = pd.read_excel(file_path)
else:
    df = pd.read_csv(file_path)

print(f"Dataset columns: {df.columns.to_list()}")

# Select only the relevant columns matching data processor's expected schema
columns_to_keep = [
    "Card Name",
    "Issuer",
    "Description",
    "Annual Fee",
    "Joining Fee",
    "Category",
    "Rewards Category",
    "Eligibility"
]

df_cleaned = df[columns_to_keep].copy()

# Function to parse list-like fields stored as strings into actual Python lists
def parse_list_field(field):
    if isinstance(field, list):
        return field
    if isinstance(field, str):
        try:
            import ast
            parsed = ast.literal_eval(field)
            if isinstance(parsed, list):
                return [str(x).strip() for x in parsed]
            return [str(parsed).strip()]
        except:
            # fallback for comma separated strings
            return [x.strip() for x in field.split(',') if x.strip()]
    return []

# Apply parsing on list-like columns
for col in ["Rewards Category", "Eligibility", "Category"]:
    df_cleaned[col] = df_cleaned[col].apply(parse_list_field)

# Clean numeric columns: remove currency symbols and convert to floats
for col in ["Annual Fee", "Joining Fee"]:
    df_cleaned[col] = df_cleaned[col].astype(str).str.replace('₹', '').str.replace(',', '').str.strip()
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce').fillna(0).astype(float)

print(f"Number of credit/debit cards loaded: {len(df_cleaned)}")

# Show the first 10 rows for verification
display(df_cleaned.head(10))

# Optionally save cleaned dataset locally (for verification or downstream use)
cleaned_data_path = "Cleaned_Credit_Card_Data.xlsx"
df_cleaned.to_excel(cleaned_data_path, index=False)
print(f"Cleaned dataset saved as {cleaned_data_path}")
# Out:
# Loaded configuration:
# {'weaviate_cluster_url': '9rl2jxlhs7oti6iig2n2iw.c0.asia-southeast1.gcp.weaviate.cloud', 'weaviate_api_key': 'RGZ2MzJjNVhVNDJHVzFaYl9lRTZzK1ZieDdaYWhOMExtV0JrZU4raUFBTjcvdlhyNStOa0lCU1ZhclEwPV92MjAw', 'tavily_api_key': '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', 'credit_card_data_path': 'Indian_Banks_Card_Dataset.xlsx'}
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 30
#      28 # Read Excel or CSV file based on file extension
#      29 if file_path.endswith(".xlsx") or file_path.endswith(".xls"):
# ---> 30     df = pd.read_excel(file_path)
#      31 else:
#      32     df = pd.read_csv(file_path)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
# CreditCard_Recommendation.ipynb

# Setup and Imports
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
from IPython.display import display, HTML

# Load environment variables from .env file
load_dotenv()

# Get configuration variables from environment
config = {
    "weaviate_cluster_url": os.getenv("WEAVIATE_CLUSTER_URL"),
    "weaviate_api_key": os.getenv("WEAVIATE_API_KEY"),
    "tavily_api_key": os.getenv("TAVILY_API_KEY"),
    "credit_card_data_path": os.getenv("CREDIT_CARD_DATA_PATH")
}

print("Loaded configuration:")
print(config)

# Load your credit/debit card dataset using the provided path
file_path = config["credit_card_data_path"]

# Read Excel or CSV file based on file extension
if file_path.endswith(".xlsx") or file_path.endswith(".xls"):
    df = pd.read_excel(file_path)
else:
    df = pd.read_csv(file_path)

print(f"Dataset columns: {df.columns.to_list()}")

# Select only the relevant columns matching data processor's expected schema
columns_to_keep = [
    "Card Name",
    "Issuer",
    "Description",
    "Annual Fee",
    "Joining Fee",
    "Category",
    "Rewards Category",
    "Eligibility"
]

df_cleaned = df[columns_to_keep].copy()

# Function to parse list-like fields stored as strings into actual Python lists
def parse_list_field(field):
    if isinstance(field, list):
        return field
    if isinstance(field, str):
        try:
            import ast
            parsed = ast.literal_eval(field)
            if isinstance(parsed, list):
                return [str(x).strip() for x in parsed]
            return [str(parsed).strip()]
        except:
            # fallback for comma separated strings
            return [x.strip() for x in field.split(',') if x.strip()]
    return []

# Apply parsing on list-like columns
for col in ["Rewards Category", "Eligibility", "Category"]:
    df_cleaned[col] = df_cleaned[col].apply(parse_list_field)

# Clean numeric columns: remove currency symbols and convert to floats
for col in ["Annual Fee", "Joining Fee"]:
    df_cleaned[col] = df_cleaned[col].astype(str).str.replace('₹', '').str.replace(',', '').str.strip()
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce').fillna(0).astype(float)

print(f"Number of credit/debit cards loaded: {len(df_cleaned)}")

# Show the first 10 rows for verification
display(df_cleaned.head(10))

# Optionally save cleaned dataset locally (for verification or downstream use)
cleaned_data_path = "Cleaned_Credit_Card_Data.xlsx"
df_cleaned.to_excel(cleaned_data_path, index=False)
print(f"Cleaned dataset saved as {cleaned_data_path}")

# %%
# CreditCard_Recommendation.ipynb

# 🔁 Ensure dotenv is installed
import sys
# !{sys.executable} -m pip install -q python-dotenv

# 📦 Setup and Imports
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
from IPython.display import display, HTML

# 🔒 Load environment variables from .env file
load_dotenv()

# 🔧 Get configuration variables from environment
config = {
    "weaviate_cluster_url": os.getenv("WEAVIATE_CLUSTER_URL"),
    "weaviate_api_key": os.getenv("WEAVIATE_API_KEY"),
    "tavily_api_key": os.getenv("TAVILY_API_KEY"),
    "credit_card_data_path": os.getenv("CREDIT_CARD_DATA_PATH")
}

print("Loaded configuration:")
print(config)

# 📂 Load your credit/debit card dataset using the provided path
file_path = config["credit_card_data_path"]

# 📊 Read Excel or CSV file based on file extension
if file_path.endswith(".xlsx") or file_path.endswith(".xls"):
    df = pd.read_excel(file_path)
else:
    df = pd.read_csv(file_path)

print(f"Dataset columns: {df.columns.to_list()}")

# 🧹 Select only the relevant columns
columns_to_keep = [
    "Card Name",
    "Issuer",
    "Description",
    "Annual Fee",
    "Joining Fee",
    "Category",
    "Rewards Category",
    "Eligibility"
]

df_cleaned = df[columns_to_keep].copy()

# 🧠 Function to parse list-like fields stored as strings
def parse_list_field(field):
    if isinstance(field, list):
        return field
    if isinstance(field, str):
        try:
            import ast
            parsed = ast.literal_eval(field)
            if isinstance(parsed, list):
                return [str(x).strip() for x in parsed]
            return [str(parsed).strip()]
        except:
            return [x.strip() for x in field.split(',') if x.strip()]
    return []

# 🔄 Apply parsing on list-like columns
for col in ["Rewards Category", "Eligibility", "Category"]:
    df_cleaned[col] = df_cleaned[col].apply(parse_list_field)

# 💰 Clean numeric columns: remove symbols and convert to floats
for col in ["Annual Fee", "Joining Fee"]:
    df_cleaned[col] = df_cleaned[col].astype(str).str.replace('₹', '').str.replace(',', '').str.strip()
    df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce').fillna(0).astype(float)

print(f"Number of credit/debit cards loaded: {len(df_cleaned)}")

# 🔍 Show the first 10 rows
display(df_cleaned.head(10))

# 💾 Optionally save cleaned dataset
cleaned_data_path = "Cleaned_Credit_Card_Data.xlsx"
df_cleaned.to_excel(cleaned_data_path, index=False)
print(f"Cleaned dataset saved as {cleaned_data_path}")
